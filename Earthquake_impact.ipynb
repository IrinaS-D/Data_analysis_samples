# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import copy

df = pd.read_csv("Emdat1_public_2023_02_14_query_uid-QKBw5b.csv")

# %%
df
# Out:
#             Dis No  Year  Seq           Glide Disaster Group  \
# 0    2010-0692-ITA  2010  692             NaN        Natural
# 1    2010-0601-BEL  2010  601             NaN        Natural
# 2    2010-0619-BIH  2010  619  FL-2010-000248        Natural
# 3    2010-0193-CZE  2010  193             NaN        Natural
# 4    2010-0233-FRA  2010  233             NaN        Natural
# ..             ...   ...  ...             ...            ...
# 589  2022-0401-ITA  2022  401             NaN        Natural
# 590  2022-0465-PRT  2022  465             NaN        Natural
# 591  2022-0275-RUS  2022  275             NaN        Natural
# 592  2022-0473-RUS  2022  473             NaN        Natural
# 593  2023-0022-SRB  2023   22             NaN        Natural
#
#     Disaster Subgroup          Disaster Type  Disaster Subtype  \
# 0      Meteorological                  Storm  Convective storm
# 1        Hydrological                  Flood    Riverine flood
# ...

# %%
df1 = df[["Year", "Country", "Location", "River Basin","Disaster Group", "Disaster Subgroup", "Disaster Type", "Disaster Subtype", "Event Name", "Origin", "Associated Dis", "Start Month", "No Affected","No Homeless", "Total Deaths", "Total Affected", "Reconstruction Costs, Adjusted ('000 US$)", "Insured Damages ('000 US$)", "Insured Damages, Adjusted ('000 US$)", "Total Damages ('000 US$)", "Total Damages, Adjusted ('000 US$)"]]
df1
# Out:
#      Year                   Country  \
# 0    2010                     Italy
# 1    2010                   Belgium
# 2    2010    Bosnia and Herzegovina
# 3    2010      Czech Republic (the)
# 4    2010                    France
# ..    ...                       ...
# 589  2022                     Italy
# 590  2022                  Portugal
# 591  2022  Russian Federation (the)
# 592  2022  Russian Federation (the)
# 593  2023                    Serbia
#
#                                               Location     River Basin  \
# 0    Veneto, Toscana, Liguria, Valle D'aosta, Lomba...             NaN
# 1    Region de Bruxelles-Capitale, Vlaams Gewest, R...             NaN
# 2    Tomislavgrad, Drvar municipalities (Zapadnobos...           Drina
# 3    Opava, Bruntal, Novy Jicin, Frydek-Mistek, Ost...     Becva river
# 4    Draguignan, Les Arcs, Figanières, Roquebrune s...             NaN
# ..                                                 ...             ...
# ...

# %%
df2 = df1[["Country", "Total Affected"]]
df2
# Out:
#                       Country  Total Affected
# 0                       Italy             5.0
# 1                     Belgium           690.0
# 2      Bosnia and Herzegovina         20000.0
# 3        Czech Republic (the)          1200.0
# 4                      France             NaN
# ..                        ...             ...
# 589                     Italy             NaN
# 590                  Portugal             NaN
# 591  Russian Federation (the)          2202.0
# 592  Russian Federation (the)           750.0
# 593                    Serbia           210.0
#
# [594 rows x 2 columns]

# %%
df_affected = df2.groupby("Country").sum()
print(df_affected)
# Out:
#                                                     Total Affected
# Country
# Albania                                                   520511.0
# Austria                                                      543.0
# Belarus                                                   143494.0
# Belgium                                                   102711.0
# Bosnia and Herzegovina                                   1315668.0
# Bulgaria                                                   58859.0
# Canary Is                                                   6888.0
# Croatia                                                   245391.0
# Czech Republic (the)                                     1305223.0
# Denmark                                                        3.0
# Estonia                                                        0.0
# France                                                    625531.0
# Germany                                                     8628.0
# ...

# %%
df_total = df_affected.sort_values(by="Total Affected", ascending=False)
df_total
# Out:
#                                                     Total Affected
# Country
# Bosnia and Herzegovina                                   1315668.0
# Czech Republic (the)                                     1305223.0
# France                                                    625531.0
# Russian Federation (the)                                  615811.0
# Albania                                                   520511.0
# Croatia                                                   245391.0
# Macedonia (the former Yugoslav Republic of)               239743.0
# Hungary                                                   226445.0
# Serbia                                                    208632.0
# Ukraine                                                   189813.0
# Greece                                                    159427.0
# Belarus                                                   143494.0
# Poland                                                    112207.0
# ...

# %%
df_10 = df_total.head(10)
df_10
# Out:
#                                              Total Affected
# Country
# Bosnia and Herzegovina                            1315668.0
# Czech Republic (the)                              1305223.0
# France                                             625531.0
# Russian Federation (the)                           615811.0
# Albania                                            520511.0
# Croatia                                            245391.0
# Macedonia (the former Yugoslav Republic of)        239743.0
# Hungary                                            226445.0
# Serbia                                             208632.0
# Ukraine                                            189813.0

# %%
# initialize list of lists
country_pop = [['Bosnia and Herzegovina', 3475000], ['Czech Republic (the)', 10516707], ['France', 68042591], ['Russian Federation (the)', 147182123], ['Albania', 2793592], ['Croatia', 3871833], ['Macedonia (the former Yugoslav Republic of)', 1836713], ['Hungary', 9678000], ['Serbia', 6690887], ['Ukraine', 41167336]]
  
# Create the pandas DataFrame
df_cpop = pd.DataFrame(country_pop, columns=['Country', 'Population'])
  
# print dataframe.
df_cpop
# Out:
#                                        Country  Population
# 0                       Bosnia and Herzegovina     3475000
# 1                         Czech Republic (the)    10516707
# 2                                       France    68042591
# 3                     Russian Federation (the)   147182123
# 4                                      Albania     2793592
# 5                                      Croatia     3871833
# 6  Macedonia (the former Yugoslav Republic of)     1836713
# 7                                      Hungary     9678000
# 8                                       Serbia     6690887
# 9                                      Ukraine    41167336

# %%
df_join = df_10.join(df_cpop.set_index('Country'), on='Country')
print(df_join)
# Out:
#                                              Total Affected  Population
# Country
# Bosnia and Herzegovina                            1315668.0     3475000
# Czech Republic (the)                              1305223.0    10516707
# France                                             625531.0    68042591
# Russian Federation (the)                           615811.0   147182123
# Albania                                            520511.0     2793592
# Croatia                                            245391.0     3871833
# Macedonia (the former Yugoslav Republic of)        239743.0     1836713
# Hungary                                            226445.0     9678000
# Serbia                                             208632.0     6690887
# Ukraine                                            189813.0    41167336
